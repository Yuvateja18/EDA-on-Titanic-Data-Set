# %%
# !pip install pyforest
import pyforest

# %%
data=pd.read_csv("train.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
 data.shape #shows rows and cols
# Out:
# (891, 12)

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# The LabelEncoder is useful for converting categorical labels into numerical values,
# import LabelEncorder
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
data['Sex'] = label_encoder.fit_transform(data['Sex'])
data['Sex'].value_counts()
# Out:
# Sex
# 1    577
# 0    314
# Name: count, dtype: int64

# %%
# here male==1 and female==0
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
data=data.drop("Name",axis=1)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0              1         0       3    1  22.0      1      0         A/5 21171
# 1              2         1       1    0  38.0      1      0          PC 17599
# 2              3         1       3    0  26.0      0      0  STON/O2. 3101282
# 3              4         1       1    0  35.0      1      0            113803
# 4              5         0       3    1  35.0      0      0            373450
# ..           ...       ...     ...  ...   ...    ...    ...               ...
# 886          887         0       2    1  27.0      0      0            211536
# 887          888         1       1    0  19.0      0      0            112053
# 888          889         0       3    0   NaN      1      2        W./C. 6607
# 889          890         1       1    1  26.0      0      0            111369
# 890          891         0       3    1  32.0      0      0            370376
#
#         Fare Cabin Embarked
# ...

# %%
data=data.drop(["Ticket","Cabin"],axis=1)
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0              1         0       3    1  22.0      1      0   7.2500        S
# 1              2         1       1    0  38.0      1      0  71.2833        C
# 2              3         1       3    0  26.0      0      0   7.9250        S
# 3              4         1       1    0  35.0      1      0  53.1000        S
# 4              5         0       3    1  35.0      0      0   8.0500        S
# ..           ...       ...     ...  ...   ...    ...    ...      ...      ...
# 886          887         0       2    1  27.0      0      0  13.0000        S
# 887          888         1       1    0  19.0      0      0  30.0000        S
# 888          889         0       3    0   NaN      1      2  23.4500        S
# 889          890         1       1    1  26.0      0      0  30.0000        C
# 890          891         0       3    1  32.0      0      0   7.7500        Q
#
# [891 rows x 9 columns]

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         2
# dtype: int64

# %%
data["Age"].median()
# Out:
# 28.0

# %%
# here we fill median value to null places in Age
data["Age"]=data["Age"].fillna(value=data["Age"].median())
data.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       2
# dtype: int64

# %%
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0              1         0       3    1  22.0      1      0   7.2500        S
# 1              2         1       1    0  38.0      1      0  71.2833        C
# 2              3         1       3    0  26.0      0      0   7.9250        S
# 3              4         1       1    0  35.0      1      0  53.1000        S
# 4              5         0       3    1  35.0      0      0   8.0500        S
# ..           ...       ...     ...  ...   ...    ...    ...      ...      ...
# 886          887         0       2    1  27.0      0      0  13.0000        S
# 887          888         1       1    0  19.0      0      0  30.0000        S
# 888          889         0       3    0  28.0      1      2  23.4500        S
# 889          890         1       1    1  26.0      0      0  30.0000        C
# 890          891         0       3    1  32.0      0      0   7.7500        Q
#
# [891 rows x 9 columns]

# %%
# embarked
g=data.groupby("Survived")
g["Embarked"].value_counts()
# Out:
# Survived  Embarked
# 0         S           427
#           C            75
#           Q            47
# 1         S           217
#           C            93
#           Q            30
# Name: count, dtype: int64

# %%
data["Embarked"].isna().sum()
# Out:
# 2

# %%
# here we fill null to S due to hign in count

data["Embarked"]=data["Embarked"].fillna(value="S")
data["Embarked"].isna().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
# Here data has no null values

# %%
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0              1         0       3    1  22.0      1      0   7.2500        S
# 1              2         1       1    0  38.0      1      0  71.2833        C
# 2              3         1       3    0  26.0      0      0   7.9250        S
# 3              4         1       1    0  35.0      1      0  53.1000        S
# 4              5         0       3    1  35.0      0      0   8.0500        S
# ..           ...       ...     ...  ...   ...    ...    ...      ...      ...
# 886          887         0       2    1  27.0      0      0  13.0000        S
# 887          888         1       1    0  19.0      0      0  30.0000        S
# 888          889         0       3    0  28.0      1      2  23.4500        S
# 889          890         1       1    1  26.0      0      0  30.0000        C
# 890          891         0       3    1  32.0      0      0   7.7500        Q
#
# [891 rows x 9 columns]

# %%
# Data Visualization

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
data['Sex'] = label_encoder.fit_transform(data['Sex'])
data['Sex'].value_counts()
# Out:
# Sex
# 1    577
# 0    314
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Assuming data is a pandas DataFrame
sex_counts = data["Sex"].value_counts()
print(sex_counts)
# Mapping categorical values to human-readable labels
label_mapping = {0: "Male", 1: "Female"}  # Adjust keys according to your dataset encoding
sex_counts.index = sex_counts.index.map(label_mapping)

# Create a bar plot
plt.bar(sex_counts.index, sex_counts.values)

plt.xlabel("Sex")
plt.ylabel("Count")
plt.title("Distribution of Sex")
plt.show()
# Out:
# Sex
# 1    577
# 0    314
# Name: count, dtype: int64

# %%
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0              1         0       3    1  22.0      1      0   7.2500        S
# 1              2         1       1    0  38.0      1      0  71.2833        C
# 2              3         1       3    0  26.0      0      0   7.9250        S
# 3              4         1       1    0  35.0      1      0  53.1000        S
# 4              5         0       3    1  35.0      0      0   8.0500        S
# ..           ...       ...     ...  ...   ...    ...    ...      ...      ...
# 886          887         0       2    1  27.0      0      0  13.0000        S
# 887          888         1       1    0  19.0      0      0  30.0000        S
# 888          889         0       3    0  28.0      1      2  23.4500        S
# 889          890         1       1    1  26.0      0      0  30.0000        C
# 890          891         0       3    1  32.0      0      0   7.7500        Q
#
# [891 rows x 9 columns]

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
data['Embarked'] = label_encoder.fit_transform(data['Embarked'])
data['Embarked'].value_counts()
# Out:
# Embarked
# 2    646
# 0    168
# 1     77
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=data, x="Embarked", hue="Survived")  # Pass column names as strings

# Adding labels and title
plt.xlabel("Port of Embarkation")
plt.ylabel("Count")
plt.title("Survival Count by Embarkation Port")
plt.legend(title="Survived", labels=["Did Not Survive", "Survived"])  # Customize legend labels

plt.show()

# %%
data.corr()
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.005007 -0.035144  0.042939  0.034212 -0.057527
# Survived       -0.005007  1.000000 -0.338481 -0.543351 -0.064910 -0.035322
# Pclass         -0.035144 -0.338481  1.000000  0.131900 -0.339898  0.083081
# Sex             0.042939 -0.543351  0.131900  1.000000  0.081163 -0.114631
# Age             0.034212 -0.064910 -0.339898  0.081163  1.000000 -0.233296
# SibSp          -0.057527 -0.035322  0.083081 -0.114631 -0.233296  1.000000
# Parch          -0.001652  0.081629  0.018443 -0.245489 -0.172482  0.414838
# Fare            0.012658  0.257307 -0.549500 -0.182333  0.096688  0.159651
# Embarked        0.013128 -0.167675  0.162098  0.108262 -0.018754  0.068230
#
#                 Parch      Fare  Embarked
# PassengerId -0.001652  0.012658  0.013128
# Survived     0.081629  0.257307 -0.167675
# Pclass       0.018443 -0.549500  0.162098
# Sex         -0.245489 -0.182333  0.108262
# ...

# %%
data.plot(x="Survived",y=["SibSp","Parch"], kind="bar")
plt.show()

# %%
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0              1         0       3    1  22.0      1      0   7.2500         2
# 1              2         1       1    0  38.0      1      0  71.2833         0
# 2              3         1       3    0  26.0      0      0   7.9250         2
# 3              4         1       1    0  35.0      1      0  53.1000         2
# 4              5         0       3    1  35.0      0      0   8.0500         2
# ..           ...       ...     ...  ...   ...    ...    ...      ...       ...
# 886          887         0       2    1  27.0      0      0  13.0000         2
# 887          888         1       1    0  19.0      0      0  30.0000         2
# 888          889         0       3    0  28.0      1      2  23.4500         2
# 889          890         1       1    1  26.0      0      0  30.0000         0
# 890          891         0       3    1  32.0      0      0   7.7500         1
#
# [891 rows x 9 columns]

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
data.to_csv("updatd_train.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0              1         0       3    1  22.0      1      0   7.2500         2
# 1              2         1       1    0  38.0      1      0  71.2833         0
# 2              3         1       3    0  26.0      0      0   7.9250         2
# 3              4         1       1    0  35.0      1      0  53.1000         2
# 4              5         0       3    1  35.0      0      0   8.0500         2
# ..           ...       ...     ...  ...   ...    ...    ...      ...       ...
# 886          887         0       2    1  27.0      0      0  13.0000         2
# 887          888         1       1    0  19.0      0      0  30.0000         2
# 888          889         0       3    0  28.0      1      2  23.4500         2
# 889          890         1       1    1  26.0      0      0  30.0000         0
# 890          891         0       3    1  32.0      0      0   7.7500         1
#
# [891 rows x 9 columns]
